# %% [markdown]
# Test and train set

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1)

# %%
X, y = mnist.data, mnist.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Binary classifier

# %%
y_train_0 = (y_train == '0')
y_test_0 = (y_test == '0')

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf = SGDClassifier(n_jobs=-1)
sgd_clf.fit(X_train, y_train_0)
# Out:
# SGDClassifier(n_jobs=-1)

# %%
y_train_pred = sgd_clf.predict(X_train)
y_test_pred = sgd_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

train_accuracy = accuracy_score(y_train_0, y_train_pred)
test_accuracy = accuracy_score(y_test_0, y_test_pred)

# %%
train_accuracy
# Out:
# 0.9886071428571429

# %%
test_accuracy
# Out:
# 0.9862857142857143

# %%
import pickle

with open('sgd_acc.pkl', 'wb') as f:
    pickle.dump([train_accuracy, test_accuracy], f)

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(sgd_clf, X_train, y_train_0, cv=3, scoring='accuracy', n_jobs=-1)
cv_scores
# Out:
# array([0.98832164, 0.98650024, 0.98805314])

# %%
with open("sgd_cva.pkl", 'wb') as f:
    pickle.dump(cv_scores, f)

# %% [markdown]
# Whole set classifier

# %%
sgd_clf.fit(X_train, y_train)
y_test_pred = sgd_clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

conf_mx = confusion_matrix(y_test, y_test_pred)
conf_mx
# Out:
# array([[1305,    0,    3,    3,    2,   18,   43,    0,   14,    6],
#        [   0, 1506,    8,    8,    1,   20,   20,   12,    7,    2],
#        [  11,   23, 1031,   48,   14,   60,  132,   23,   60,   13],
#        [   4,    7,   23, 1079,    3,  237,   23,   12,   25,   35],
#        [   1,    7,    2,    1, 1206,   15,   22,    9,    7,  102],
#        [   7,    2,    2,   12,   23, 1062,   87,    5,   17,   25],
#        [   3,    3,    5,    0,    9,    9, 1360,    0,    6,    2],
#        [   4,    3,   13,    5,   16,    8,    1, 1294,    2,   90],
#        [   9,   10,   13,   25,   10,  266,   68,   18,  873,   68],
#        [   2,    2,    4,    6,   23,   55,    2,   30,   11, 1217]],
#       dtype=int64)

# %%
with open("sgd_cmx.pkl", 'wb') as f:
    pickle.dump(conf_mx, f)
